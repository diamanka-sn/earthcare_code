# %%
import earthcarekit as eck 
#eck.create_example_config()

# %%
eck.set_config(".config/default_config.toml")

# %% [markdown]
# Generer une clé sur `https://portal.maap.eo.esa.int/earthcare/`

# %%
eck.set_config_maap_token("Token ESA")
eck.set_config_to_maap()
# Out:
# Set MAAP access token (default config updated at </home/diamankam/.config/earthcarekit/default_config.toml>)
# Set download backend to MAAP (default config updated at </home/diamankam/.config/earthcarekit/default_config.toml>)
